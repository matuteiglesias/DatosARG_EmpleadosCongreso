# %%
import pandas as pd

import sys  

reload(sys)  
sys.setdefaultencoding('utf8')

# %%
ejec_2016 = pd.read_csv('ejecucion_2016.1.1.csv').astype(float, errors  ='ignore')
ejec_2017 = pd.read_csv('ejecucion_2017.1.2.csv').astype(float, errors  ='ignore')

ejec_2017['monto_compromiso_consumido'] = ejec_2017['monto_compromiso_consumido'].str.replace(',', '.').astype(float)
ejec_2017['monto_devengado_consumido'] = ejec_2017['monto_devengado_consumido'].str.replace(',', '.').astype(float)

# %%
ejec_2016.sum()
# Out:
# programa_id                                                                 1989
# programa_desc                  Formación y Sanción LegislativaFormación y San...
# inciso_id                                                                    295
# inciso_desc                    Gastos en PersonalGastos en PersonalGastos en ...
# principal_id                                                                 521
# principal_desc                 Personal PermanentePersonal PermanentePersonal...
# parcial_id                                                                   474
# parcial_desc                   Retribución del CargoRetribuciones que no hace...
# monto_credito_vigente                                                4.66438e+09
# monto_compromiso_preventivo                                           1.4954e+06
# monto_compromiso_reservado                                                     0
# monto_compromiso_consumido                                           4.63459e+09
# monto_devengado_reservado                                                      0
# monto_devengado_consumido                                            4.63459e+09
# ejercicio_id                                                              235872
# dtype: object

# %%
(4.66438e+09 + 1.4954e+06)-4.63459e+09
# Out:
# 31285400.0

# %%
ejec_2017.sum()
# Out:
# programa_id                                                                 1921
# programa_desc                  Formación y Sanción LegislativaFormación y San...
# inciso_id                                                                    285
# inciso_desc                    Gastos en PersonalGastos en PersonalGastos en ...
# principal_id                                                                 497
# principal_desc                 Personal PermanentePersonal PermanentePersonal...
# parcial_id                                                                   452
# parcial_desc                   Retribución del CargoRetribuciones que no hace...
# monto_credito_vigente                                                6.02973e+09
# monto_compromiso_preventivo                                                    0
# monto_compromiso_reservado                                                     0
# monto_compromiso_consumido                                           5.98656e+09
# monto_devengado_reservado                                                      0
# monto_devengado_consumido                                            5.98656e+09
# ejercicio_id                                                              227921
# dtype: object

# %%
ejec_2017.nunique()
# Out:
# programa_id                      1
# programa_desc                    1
# inciso_id                        5
# inciso_desc                      5
# principal_id                     9
# principal_desc                  30
# parcial_id                      10
# parcial_desc                    98
# monto_credito_vigente          105
# monto_compromiso_preventivo      1
# monto_compromiso_reservado       1
# monto_compromiso_consumido     113
# monto_devengado_reservado        1
# monto_devengado_consumido      113
# ejercicio_id                     1
# dtype: int64

# %%
ejec_2017[['inciso_desc', 'principal_desc']].drop_duplicates()

ejec_2017.groupby(['inciso_desc', 'principal_desc']).sum()[['monto_credito_vigente', 'monto_compromiso_consumido']].style.bar(subset=['monto_credito_vigente', 'monto_compromiso_consumido'], color=['#d65f5f'])
# Out:
# <style  type="text/css" >
#     #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row11_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.8%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.8%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.0%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row19_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row20_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 0%);
#         }    #T_34ea3a9e_7f44_11e8_b629_5ce0c5892623row20_col1 {
#             width:  10em;
#              height:  80%;

# %%
# ejec_2016[['inciso_desc', 'principal_desc']].drop_duplicates()

(ejec_2017.groupby(['inciso_desc', 'principal_desc', 'parcial_desc']).sum()[[
        'monto_credito_vigente', 'monto_compromiso_consumido'
    ]].sort_values(by = 'monto_credito_vigente', ascending = False
                  ).head(25)/(12*256*17)).style.bar(subset=['monto_credito_vigente', 'monto_compromiso_consumido'], color=['#d65f5f'])
# Out:
# <style  type="text/css" >
#     #T_3b01c324_7f45_11e8_b629_5ce0c5892623row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.2%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.3%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.1%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.3%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.4%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.5%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.5%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.6%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.7%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.8%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.4%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.5%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.9%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.9%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.7%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.6%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.8%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.8%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.0%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.7%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row19_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0%);
#         }    #T_3b01c324_7f45_11e8_b629_5ce0c5892623row20_col0 {
#             width:  10em;
#              height:  80%;
#             background:  line
